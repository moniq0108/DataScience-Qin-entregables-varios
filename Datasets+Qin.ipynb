# %%
import pandas as pd

#Data set 1: Musica y salud mental
from google.colab import drive
import os
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# %cd '/content/gdrive/My Drive'
df= pd.read_excel('music_mentalhealth.xlsx')
print(df.head(5))
# Out:
# /content/gdrive/My Drive
#                         Age Primary streaming service  Hours per day  \
# 0  8/27/2022 19:29:02  18.0                   Spotify            3.0
# 1  8/27/2022 19:57:31  63.0                   Pandora            1.5
# 2  8/27/2022 21:28:18  18.0                   Spotify            4.0
# 3  8/27/2022 21:40:40  61.0             YouTube Music            2.5
# 4  8/27/2022 21:54:47  18.0                   Spotify            4.0
#
#   While working Instrumentalist Composer         Fav genre Exploratory  \
# 0           Yes             Yes      Yes             Latin         Yes
# 1           Yes              No       No              Rock         Yes
# 2            No              No       No  Video game music          No
# 3           Yes              No      Yes              Jazz         Yes
# 4           Yes              No       No               R&B         Yes
#
#   Foreign languages  ...  Frequency [R&B]  Frequency [Rap] Frequency [Rock]  \
# ...

# %%
df.head()
# Out:
#                         Age Primary streaming service  Hours per day  \
# 0  8/27/2022 19:29:02  18.0                   Spotify            3.0
# 1  8/27/2022 19:57:31  63.0                   Pandora            1.5
# 2  8/27/2022 21:28:18  18.0                   Spotify            4.0
# 3  8/27/2022 21:40:40  61.0             YouTube Music            2.5
# 4  8/27/2022 21:54:47  18.0                   Spotify            4.0
#
#   While working Instrumentalist Composer         Fav genre Exploratory  \
# 0           Yes             Yes      Yes             Latin         Yes
# 1           Yes              No       No              Rock         Yes
# 2            No              No       No  Video game music          No
# 3           Yes              No      Yes              Jazz         Yes
# 4           Yes              No       No               R&B         Yes
#
#   Foreign languages  ...  Frequency [R&B]  Frequency [Rap] Frequency [Rock]  \
# ...

# %% [markdown]
# Hours per day: Esta columna indica la cantidad de horas destinadas a escuchar musica por dia. Tiene potencial ya que cuanto mayor sean las horas, mejor es la salud mental del individuo.

# %%
#Data set 2: Sleep quality
import pandas as pd

from google.colab import drive
import os
drive.mount('/content/gdrive')
# %cd '/content/gdrive/My Drive'
df= pd.read_excel('Sleepdataex.xlsx')
print(df.head(5))
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# /content/gdrive/My Drive
#                 Start                 End  Sleep quality Time in bed Wake up  \
# 0                 NaT                 NaT            NaN         NaN     NaN
# 1 2014-12-29 22:57:49 2014-12-30 07:30:13           1.00    08:32:00      :)
# 2                 NaT                 NaT            NaN         NaN     NaN
# 3 2014-12-30 21:17:50 2014-12-30 21:33:54           0.03    00:16:00      :|
# 4                 NaT                 NaT            NaN         NaN     NaN
#
#      Sleep Notes  Heart rate  Activity (steps)
# 0            NaN         NaN               NaN
# 1            NaN        59.0               0.0
# 2            NaN         NaN               NaN
# 3  Stressful day        72.0               0.0
# 4            NaN         NaN               NaN

# %%
df.dropna(subset = ['Start'])
# Out:
#                    Start                 End  Sleep quality Time in bed  \
# 1    2014-12-29 22:57:49 2014-12-30 07:30:13           1.00    08:32:00
# 3    2014-12-30 21:17:50 2014-12-30 21:33:54           0.03    00:16:00
# 5    2014-12-30 22:42:49 2014-12-31 07:13:31           0.98    08:30:00
# 7    2014-12-31 22:31:01 2015-01-01 06:03:01           0.65    07:32:00
# 9    2015-01-01 22:12:10 2015-01-02 04:56:35           0.72    06:44:00
# ...                  ...                 ...            ...         ...
# 1765 2018-02-12 21:54:14 2018-02-13 07:02:15           0.91    09:08:00
# 1767 2018-02-13 23:49:19 2018-02-14 07:00:53           0.81    07:11:00
# 1769 2018-02-14 21:24:05 2018-02-15 06:20:52           0.71    08:56:00
# 1771 2018-02-15 21:36:32 2018-02-16 06:50:31           0.80    09:13:00
# 1773 2018-02-16 22:52:29 2018-02-17 07:48:04           0.91    08:55:00
#
#      Wake up             Sleep Notes  Heart rate  Activity (steps)
# ...

# %% [markdown]
# Time in bed: Esta columna indica la cantidad de horas dormidas. Tiene potencial ya que cuanto mayor sean las horas, mejor es la calidad de sueño del individuo.

# %%
#Data set 3: Nutricion

import pandas as pd

from google.colab import drive
import os
drive.mount('/content/gdrive')
# %cd '/content/gdrive/My Drive'
df= pd.read_csv('Nutrition.csv',sep=',')
print(df.head(5))
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# /content/gdrive/My Drive
#      Company   Category                           Product Per Serve Size  \
# 0  Pizza Hut  All Meals          Corn n Cheese (Personal)        143.5 g
# 1  Pizza Hut  All Meals          Country Feast (Personal)          178 g
# 2  Pizza Hut  All Meals          Double Cheese (Personal)          143 g
# 3  Pizza Hut  All Meals  Double Paneer Supreme (Personal)        174.5 g
# 4  Pizza Hut  All Meals          Farmer`s Pick (Personal)          177 g
#
#    Energy (kCal)  Carbohydrates (g)  Protein (g)  Fiber (g)  Sugar (g)  \
# 0         432.60              65.64        17.91       3.85        0.0
# 1         407.60              67.11        16.73       7.19        0.0
# 2         423.33              59.97        18.26       3.49        0.0
# 3         474.03              52.86        20.07       3.79        0.0
# ...

# %%
df.head()
# Out:
#      Company   Category                           Product Per Serve Size  \
# 0  Pizza Hut  All Meals          Corn n Cheese (Personal)        143.5 g
# 1  Pizza Hut  All Meals          Country Feast (Personal)          178 g
# 2  Pizza Hut  All Meals          Double Cheese (Personal)          143 g
# 3  Pizza Hut  All Meals  Double Paneer Supreme (Personal)        174.5 g
# 4  Pizza Hut  All Meals          Farmer`s Pick (Personal)          177 g
#
#    Energy (kCal)  Carbohydrates (g)  Protein (g)  Fiber (g)  Sugar (g)  \
# 0         432.60              65.64        17.91       3.85        0.0
# 1         407.60              67.11        16.73       7.19        0.0
# 2         423.33              59.97        18.26       3.49        0.0
# 3         474.03              52.86        20.07       3.79        0.0
# 4         408.16              53.93        19.91       2.46        0.0
#
#    Total Fat (g)  Saturated Fat (g)  Trans Fat (g)  Cholesterol (mg)  \
# ...

# %% [markdown]
# Saturated Fat: Esta columna indica la cantidad de gramos de grasa saturada que contiene la porcion servida. Tiene potencial para demostrar que la comida rapida no es sana ya que idealmente el peso de la grasa saturada no debe exceder del 10 porciento de las calorias. Sabiendo que cada gramo de grasa saturada equivale a 9 calorias, si tomasemos como ejemplo la primera fila, el 10% de 432.60 calorias es 43.26 calorias, y la equivalencia de esta en gramos de grasa saturada es 4.80 gr.
